# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import xlrd
import openpyxl
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import math
import _pickle
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import folium
from folium.plugins import HeatMap

# %%
with open("pkls/r6_pq.pkl", "rb") as f:
    a = _pickle.load(f)
with open("pkls/list_item.pkl", "rb") as f:
    list_item = _pickle.load(f)
with open("pkls/m3_list.pkl", "rb") as f:
    m3_list = _pickle.load(f)
with open('pkls/df_m3_item.pkl', 'rb') as f:
    df_m3_item_p = _pickle.load(f)
with open('pkls/df_sum_latlng.pkl', 'rb') as f:
    df_sum_latlng = _pickle.load(f)
with open('pkls/df_sum.pkl', 'rb') as f:
    df_sum = _pickle.load(f)

# %%
gau_P_m3_T_latlng = pd.read_csv("csvs/matrix_mesh_k.csv", encoding='utf-16', index_col=0)

# %%
k_item_array = np.c_[list_item, a['Q'].T]
k_item = pd.DataFrame(k_item_array, columns=['item',1,2,3,4,5,6])

# %%
lat_list, lng_list = df_sum_latlng.lat, df_sum_latlng.lng

# %%
# def to_rate():
df_sum_nan0 = df_sum[df_sum.total != 0]
for key, col in df_sum_nan0.iteritems():
    df_sum_nan0[key] = col / df_sum_nan0['total']
df_sum_nan0 = df_sum_nan0.drop('total', axis=1)
# Out:
# /Users/tomo/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_sum_nan0
# Out:
#                布団類    じゅうたん類        鞄類       座布団         枕     クッション  \
# 53390336  0.384615  0.153846  0.000000  0.076923  0.000000  0.230769
# 53390337  0.400000  0.033333  0.000000  0.066667  0.166667  0.166667
# 53390338  1.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 53390344  0.222222  0.333333  0.000000  0.000000  0.000000  0.444444
# 53390345  0.387097  0.193548  0.000000  0.161290  0.096774  0.161290
# 53390346  0.500000  0.250000  0.000000  0.125000  0.062500  0.000000
# 53390347  0.600000  0.000000  0.000000  0.000000  0.200000  0.200000
# 53390348  0.200000  0.000000  0.000000  0.200000  0.600000  0.000000
# 53390354  0.428571  0.000000  0.000000  0.000000  0.000000  0.571429
# 53390355  0.416667  0.208333  0.000000  0.083333  0.000000  0.208333
# 53390356  0.636364  0.181818  0.000000  0.000000  0.000000  0.181818
# 53390357  0.333333  0.000000  0.000000  0.000000  0.000000  0.333333
# 53390358  0.428571  0.142857  0.000000  0.285714  0.142857  0.000000
# ...

# %%
df_sum_rm = df_sum.drop(['鞄類', 'イス', 'ダンボール', '傘', '家電製品', '発泡スチロール'], axis=1)

# %%
total_list = list(df_sum_rm.total)

# %%
total_list
# Out:
# [13,
#  30,
#  1,
#  9,
#  31,
#  16,
#  10,
#  5,
#  0,
#  0,
#  7,
#  24,
#  11,
#  3,
#  7,
#  0,
#  0,
#  0,
#  1,
#  1,
#  13,
#  24,
#  5,
#  1,
#  11,
#  4,
#  10,
#  20,
#  43,
#  3,
#  2,
#  5,
#  1,
#  20,
#  4,
#  9,
#  2,
#  1,
#  0,
#  1,
#  1,
#  1,
#  13,
#  32,
#  0,
#  0,
#  15,
#  0,
#  14,
#  6,
#  8,
#  28,
#  29,
#  16,
#  16,
#  27,
#  7,
#  15,
#  41,
#  16,
#  11,
#  14,
#  4,
#  9,
#  2,
#  33,
#  57,
#  18,
#  22,
#  19,
#  21,
#  27,
#  25,
#  32,
#  27,
#  18,
#  8,
#  8,
#  7,
#  24,
#  0,
#  21]

# %%
df_sum_rm_nan0 = df_sum_nan0.drop(['鞄類', 'イス', 'ダンボール', '傘', '家電製品', '発泡スチロール'], axis=1)
